# %%
my_state=input("what's your state")
# Out:
# what's your state lagos

# %%
print(my_state)
# Out:
# Lagos

# %% [markdown]
# ### VAARIABLES
#
# ### Rules for defining variables
# - start with a letter or underscore
# - contains letters, letters or underscore
# - variables are case sensitive
# - you can't use python keywords to name your variables
# - names should be descriptive enough

# %%
#Variables
my_age= 12
my_Age=15

print(my_age)
# Out:
# 12

# %%
# += operator
#instead of
y= 10+6
print(y)

# do this instead

y=10
y+=6
print(y)
# Out:
# 16
# 16

# %% [markdown]
# ### DATA TYPES
# - Numeric
#   interger eg 1,2,3
#   float eg 7.5
# -string eg "Angela", "4566"

# %%
#string concatenation

v= "hello" + " Angela" #put space after Angela 
print(v)
# Out:
# hello Angela

# %%
speech= "she said 'my name is daniella'"
print(speech)

#or

val="she said \"my name is simbi\" \n make me jollof"
print (val)
# Out:
# she said 'my name is daniella'
# she said "my name is simbi"
#  make me jollof

# %%
#f string
days=365
v= (f"there are {days} in a year")

print(v)
# Out:
# there are 365 in a year

# %%
#modulo

v=(5%2)
print(v)
# Out:
# 1

# %%
#data type change
v=55
y=float(v)
print(y)
# Out:
# 55.0

# %% [markdown]
# ### Error Types
#
# # Some Errors in Python
# - Zero error : when you divide a number by 0
# - Syntax Error : Occurs when your code does not make any sense to the computer e.g this occurs when you misspelt something
# - Name Error : Occurs when you try to use a variable that has not been defined
# - Type Error : Occurs when you try to perform an operation on a variable that is not compatible with the operation
# - Index Error : Occurs when you try to access an index that is out of range in a list or string
# - Key Error : Occurs when you try to access a key that does not exist in a dictionary
# - Attribute Error : Occurs when you try to access an attribute that does not exist in an object
# - Import Error : Occurs when you try to import a module that does not exist or is not installed
#  - Value Error : Occurs when you try to convert a value to a type that is not compatible with the value
# - File Not Found Error : Occurs when you try to open a file that does not exist
# - Indentation Error : Occurs when your code is not properly indented, which is important in Python for defining blocks of code
# - Overflow Error : Occurs when a calculation exceeds the maximum limit for a numeric type
# - Memory Error : Occurs when your program runs out of memory
# - Recursion Error : Occurs when a function calls itself too many times without a base case, leading to a stack overflow
# - Stop Iteration Error : Occurs when you try to iterate over an object that has no more items to return
# - Unicode Error : Occurs when there is an issue with encoding or decoding a string that contains non-ASCII characters

# %%
def add_num(a,b):
    v=a+b
    print(v)

# %%
 add_num(2,3)
# Out:
# 5

# %%
def greeting(a):
    v= ("how are you"+ a +"welcome to today's class")
    print(v)

# %%
greeting("Tobi ")
# Out:
# how are youTobiwelcome to today's class

# %%
def welcome(a):
    print(f"how are you {a}, welcome to class")

# %%
welcome("Tobi")
# Out:
# how are you Tobi, welcome to class

# %%
age=input("how old are you?")
# Out:
# how old are you? 35

# %%
def years_left():
    name=input("what's your name?")
    age=int(input("how old are you?"))
    max_age=90
    y=max_age-age
    month= y*12
    weeks=y*52
    days=y*365
    print(f"{name} has {y} years, {month} months, {weeks} weeks & {days} days left to live")

# %%
years_left()
# Out:
# what's your name? remi
# how old are you? 55
# remi has 35 years, 420 months, 1820 weeks & 12775 days left to live

# %%
#Variable Scope

n=2

def my_num():
    n=3
    print(n)

print(n)
my_num()
# Out:
# 2
# 3

# %%
#Python key words
print, def, in, import, or, and, class, return, except, try

# %%
printx= (7+4)

print(printx)
# Out:
# 11

# %% [markdown]
# ### Conditionals
# - if
# - else
# - elif

# %%
n=2000
if n>1900:
    print("vacation in USA")

elif n==1500:
    print("vacation in Barbados")

elif n>=1000:
    print("vacation in Morocco")

else:
    print("No Vacation")
# Out:
# vacation in USA

# %% [markdown]
# ### Logical statement
# -and
# -or
# -not

# %%
#And 

my_age=63

if my_age > 50 and my_age % 2 ==0:
    print("Good age value")

else:
    print("sorry, try again later")
# Out:
# sorry, try again later

# %%
#Or

my_age=64
if my_age > 50 or my_age % 2 ==0:
    print("Good age value")

else:
    print("sorry, try again later")
# Out:
# Good age value

# %%
#Not

my_age=90
if not my_age > 70 or (not my_age % 2) ==0:
    print("Good age value")

else:
    print("sorry, try again later")
# Out:
# sorry, try again later

# %% [markdown]
# ### lIST
# student_list= ['Mouma", "Binta", "Azeez", "Mpudule", "Tobi"]

# %% [markdown]
# ### LOOPS IN PYTHON
#
# - While Loop
# - For Loop

# %%
#while loop
n=1
while n<10:
    n+=1
    print(n)

# %%
#For Loop

student_list = ["Mouma", "Binta", "Azeez", "Mpudule", "Tobi"]


for name in student_list:
    print(name)
# Out:
# Mouma
# Binta
# Azeez
# Mpudule
# Tobi

# %%
#Range
for val in range(0,10,2):
    print(val)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
#Break
for numbers in range (0,20,2):
    if numbers>15:
        print ("that's okay")
        break
    print(numbers)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# that's okay

# %%
#Continue

n=1
while n<10:
    n+=1
    if n%2==0:
        print("not available")
        continue
    print(n)
# Out:
# not available
# 3
# not available
# 5
# not available
# 7
# not available
# 9
# not available

# %%
#indefinite
while 5>1: # 5 will always be greater than 1 so it's going to be an infenite loop
    print("I am a winner")

# %% [markdown]
# ### DATA STRUCTURES
# - LISTS
# - DICTIONARY
# - TUPLES
# - SETS

# %%
#lISTS: A list is an ordered, mutable collection of values or items in a 

names_of_students = ["Mouma", "Binta", "Azeez", "Mpudule", "Tobi"]

# %%
letters= ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'k', 'l']
print(letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'k', 'l']

# %%
print(letters[3:])
print(letters[-3:])

# %%
for i in range(6,-4,-2):
    print(i)
# Out:
# 6
# 4
# 2
# 0
# -2

# %%
import random as rd
i=rd.randint(1,100)
print(i)
# Out:
# 35

# %%
# -Modules -Packages -Libraries

# %%
#data types
#strings

stri="Hello, World!"

print (stri[0])
print (stri[-1])
print (stri.lower())
print (stri.upper())
print(len(stri))
# Out:
# H
# !
# hello, world!
# HELLO, WORLD!
# 13

# %%
sent= ["Let's ", "do ", "this"]
print(sent)
# Out:
# ["Let's ", 'do ', 'this']

# %%
def combine(list1:[]):
    #.join()
    sentence="".join(list1)
    return sentence

# %%
combine(["Hello", ", ", "how ", "are ", "you?"]) == "Hello, how are you?"
# Out:
# True

# %%
combine(sent)
# Out:
# "Let's do this"

# %%
separate('Hello, how are you?') == ['Hello,', 'how', 'are', 'you?']
separate('I can code in Python!') == ['I', 'can', 'code', 'in', 'Python!']

#Challenge 2
#In this task, we seek to perform the opposite operation from Challenge 1. A string is passed through to the separate function. Your task is to write the code which will split the sentence into words, along each space character (" "), and return a list of strings.
#For example:
#>>> separate("Let's do this!")
#["Let's", 'do', 'this!']

# %%
def separate(words:str):
    lists= words.split()
    return lists

# %%
separate('Hello, how are you?') == ['Hello,', 'how', 'are', 'you?']
# Out:
# True

# %%
separate('Hello, how are you?')
# Out:
# ['Hello,', 'how', 'are', 'you?']

# %%
#write a function that finds the square root and the square of every number in the following number

list1= [2,4,6,8,10]
list2= [100, 25,64,81]

# %%
def square_squareroot(l:[]):
    square=[]
    squareroot=[]

    for i in l:
        square.append((i)**2)
        squareroot.append((i)**0.5)
    
    return square, squareroot

# %%
square_squareroot(list1)
# Out:
# ([4, 16, 36, 64, 100],
#  [1.4142135623730951,
#   2.0,
#   2.449489742783178,
#   2.8284271247461903,
#   3.1622776601683795])

# %%
# Write a function that takes in any 3 random ages of an end user as list, finds modulo 2 of each value in a list and gives the result

# %%
def age_modulo(list):
    list=(map(int, input("insert numbers seperated by space: ").split()))

    modulo=[]
    
    for n in list:
        modulo.append((n)%2)

    return modulo

# %%
age_modulo(list)
# Out:
# insert numbers seperated by space:  7 4 1
# [1, 0, 1]

# %%
# Out:
# input your age:  4 6 7
# ...

# %%
#find the square root of 22/7

v=(22/7)**0.5
print(v)
# Out:
# 1.7728105208558367

# %%
#write a function that gives your firstname as lower case and your surname in upper case

def lower_higher_Case():
    A= input("input your firstname")
    B=input("input your lastname")

    L=A.lower()
    H=B.upper()

    return L,H

# %%
lower_higher_Case()
# Out:
# input your firstname tobi
# input your lastname jaiyesimi
# ('tobi', 'JAIYESIMI')

# %%
#x = 2**5
#y = (130/5)
#z = 6* 7
#is y equal to z (True or False)

y = (130/5)
z = 6* 7

y==z
# Out:
# False

# %% [markdown]
# ### lambda, map, filtering

# %%
#Lambda

d=lambda x:x*2

# %%
#Regular function

def muli_by_2(v):
    return v*2

# %%
p= lambda z :z*2

# %%
v= list(map(lambda a: a**2, val_list)), print(v)

# %%
def squa_list(li[]):

# %%
letter= 'Gilead'

# %%
#List Comprehension

y= [character for character in letter]

print (y)
# Out:
# ['G', 'i', 'l', 'e', 'a', 'd']

# %%
#values in A greater than values in B

# %%
input_list = [1, 2, 3, 4, 4, 5, 6, 7, 7]

even_number= [char for char in input_list if char%2==0]

print(even_number)
# Out:
# [2, 4, 4, 6]

# %%
a = [1,2,3]
b = [4,5,6]
c = [7,8,9]
d = [10,11,12]

v=[e+f+g+h for e,f,g,h in zip(a,b,c,d)]

print(v)
# Out:
# [22, 26, 30]

# %%
words = ["Banana", "apple", "Zebra", "kenya", "cherry"]

words.sort(key=str.casefold)

print(words)
# Out:
# ['apple', 'Banana', 'cherry', 'kenya', 'Zebra']

# %%
pairs = [(1, 'b'), (1, 'a'), (2, 'c')]


print(sorted(pairs))
# Out:
# [(1, 'a'), (1, 'b'), (2, 'c')]

# %%
d = {"alice": 3, "bob": 1, "cara": 2}

print(sorted(d.items(), key=lambda kv: kv[0]))
# Out:
# [('alice', 3), ('bob', 1), ('cara', 2)]

# %%
#create a function sq_cube which returns a list of lists containing both the sqaure and the cube of only even numbers in a given list. the function must be able to round the number to the nearest whole number
y=[3.4, 6, 2.2]

x= [round(v) for v in y]


print(x)
# Out:
# [3, 6, 2]

# %%
def sq_cube(orig_list):
    rounded_up=[round (num) for num in orig_list]
    even_list=[]
    for num in rounded_up:
        if num%2==0:
            even_list.append(num)
    final_list=[[(num)**2, (num)**3] for num in even_list]

    return final_list

# %%
sq_cube([2.2, 5, 4, 7.2])
# Out:
# [[4, 8], [16, 64]]

# %%
def RNA(v):
    if v.startswith("AUG") and v.endswith(("UGA","UAA","UAG")):
        print(len(v))
    else:
        print ("Not readable RNA code")

# %%
def RNAA(x):
    if x[:3]=="AUG" and (x[:-3]== ("UGA") or ("UAA") or ("UAG")):
        print(len(x))
    else:
        print ("Not readable RNA code")

# %%
def rna_length(RNA):
    if RNA[0:3]== 'AUG' and RNA[-3:] in ('UGA','UAA','UAG'):
        RNA = RNA[3:]
        RNA = RNA[0 :-3]
        result = len(RNA)
        return result
    else :
        return "Not readable RNA code"

# %%
rna_length('AUGAGGCACCUUUCUGCUUCCUUAA')
# Out:
# 19

# %%
def trial(v):
    if v[:2]=="st":
        print("true")
    else:
        print("false")

# %%
trial("start")
# Out:
# true

# %%
d

# %%
remove_adjacent([1, 2, 2, 3, 4])

# %%
def removee_adjacent(nums):
    new=[]
    for i in nums:
        if i == i+1:
            new.append(num[i])
    return (new)

# %%
remove_adjacent([1, 2, 2, 3, 4])

# %%
def remove_adjacent(nums):
    new=[]
    for i in nums:
        if not new or i != new[-1]:
            new.append(i)
    print(new)

# %%
remove_adjacent([1,3,3,4,5,5])

# %%
def symmetrical_sum(nums):
    for i in range(len(nums)):
        for j in range(i+1, len(nums)):
            if nums[i]==nums[j]:
                return nums[i:j+1]

# %%
symmetrical_sum([19,13,22,41,5,18,22,15,46])

# %%
symmetrical_sum([19,13,22,41,5,18,22,15,46]) == ([22, 41, 5, 18, 22], 108)

# %%
df = pd.read_csv("New_Customers_Data.csv")

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("New_Customers_Data.csv")
df.head()
# Out:
#      CUST_ID  DTH_INIT_SOL_ID        TRAN_DATE  Post Customer PART_TRAN_TYPE  \
# 0  160450435              160  11/30/2022 0:00      160450435         CREDIT
# 1  160402430              160  11/15/2022 0:00      160402430         CREDIT
# 2  160417547              160  12/29/2022 0:00      160417547         CREDIT
# 3  160416279              160   1/19/2023 0:00      160416279         CREDIT
# 4  160416279              297   1/20/2023 0:00      160416279         CREDIT
#
#   TRAN_SUB_TYPE BU_CODE       BU_NAME GROUP_CODE      GROUP_NAME TEAM_CODE  \
# 0            NR       6  NORTH REGION        605  NRG-NORTH EAST     60502
# 1            NR       6  NORTH REGION        605  NRG-NORTH EAST     60502
# 2            NR       6  NORTH REGION        605  NRG-NORTH EAST     60502
# 3            NR       6  NORTH REGION        605  NRG-NORTH EAST     60502
# 4            NR       6  NORTH REGION        605  NRG-NORTH EAST     60502
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14112 entries, 0 to 14111
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CUST_ID            14112 non-null  int64
#  1   DTH_INIT_SOL_ID    14112 non-null  int64
#  2   TRAN_DATE          14112 non-null  object
#  3   Post Customer      14112 non-null  int64
#  4   PART_TRAN_TYPE     14112 non-null  object
#  5   TRAN_SUB_TYPE      14112 non-null  object
#  6   BU_CODE            14075 non-null  object
#  7   BU_NAME            14075 non-null  object
#  8   GROUP_CODE         14075 non-null  object
#  9   GROUP_NAME         14075 non-null  object
#  10  TEAM_CODE          14075 non-null  object
#  11  TEAM_NAME          14075 non-null  object
#  12  DESK_CODE          14075 non-null  object
#  13  DESK_NAME          14075 non-null  object
#  14  RM_CODE            14075 non-null  object
#  15  RM_NAME            14075 non-null  object
# ...

# %%
df.describe()
# Out:
#             CUST_ID  DTH_INIT_SOL_ID  Post Customer  Post TRAN_AMT_VAL
# count  1.411200e+04     14112.000000   1.411200e+04       1.411200e+04
# mean   4.182466e+08       425.117843   4.182466e+08       7.826613e+06
# std    2.007601e+08       208.744979   2.007601e+08       5.603334e+06
# min    1.010172e+08       101.000000   1.010172e+08       5.000000e+06
# 25%    2.290086e+08       246.000000   2.290086e+08       5.144712e+06
# 50%    3.884237e+08       395.000000   3.884237e+08       6.180228e+06
# 75%    5.834162e+08       601.000000   5.834162e+08       8.527082e+06
# max    8.914004e+08       999.000000   8.914004e+08       2.500000e+08

# %%
df.columns
# Out:
# Index(['CUST_ID', 'DTH_INIT_SOL_ID', 'TRAN_DATE', 'Post Customer',
#        'PART_TRAN_TYPE', 'TRAN_SUB_TYPE', 'BU_CODE', 'BU_NAME', 'GROUP_CODE',
#        'GROUP_NAME', 'TEAM_CODE', 'TEAM_NAME', 'DESK_CODE', 'DESK_NAME',
#        'RM_CODE', 'RM_NAME', 'Post TRAN_AMT_VAL', 'Post TRAN_AMT'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14112, step=1)

# %%
-Business understanding -Data Understanding -Modelling -Model Evaluation -Deployment

# %%
f= [2,3,5,6,7]

g= [(f[0])]

print (g)
print (f)
# Out:
# [2]
# [2, 3, 5, 6, 7]

# %%
f=[2,3,3,4,5]
g=[]
for i in f:
    if i==g[-1]:
        continue
        g.append(i)
    
print(g)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 g=[]
#       3 for i in f:
# ----> 4     if i==g[-1]:
#       5         continue
#       6         g.append(i)
#
# IndexError: list index out of range

# %%
def remove_adjacent(num):
    arranged_list=[]

    for i in num:
        if len(arranged_list):
            if not i == arranged_list[-1]:
                arranged_list.append(i)            
        else:
            arranged_list.append(i)
 

    return(arranged_list)

# %%
remove_adjacent([1, 2, 2, 3])
# Out:
# [1, 2, 3]

# %%
def remove_adjacent(nums):
    # your code here
    new_list = []
    for item in nums:
        if len(new_list):
            if new_list[-1]!= item:
                new_list.append(item)
        else: new_list.append(item)
                
    return new_list

# %%
remove_adjacent([1, 2, 2, 3])
# Out:
# [1, 2, 3]

# %%
#ATCGGAATGCC
#TAGCCTTACGG

# %%
def dna_compliment(code):
    compliment=[]
    for letters in code:
        if letters=="T":
            compliment.append("A")
        elif letters=="A":
            compliment.append("T")
        elif letters=="G":
            compliment.append("C")
        elif letters=="C":
            compliment.append("G")
        else: print(" invalid letter")
        
    new_code="".join(compliment)
    return(new_code)

# %%
dna_compliment("ATCGGAATHGCC")
# Out:
#  invalid letter
# 'TAGCCTTACGG'

# %%
df.columns
# Out:
# Index(['CUST_ID', 'DTH_INIT_SOL_ID', 'TRAN_DATE', 'Post Customer',
#        'PART_TRAN_TYPE', 'TRAN_SUB_TYPE', 'BU_CODE', 'BU_NAME', 'GROUP_CODE',
#        'GROUP_NAME', 'TEAM_CODE', 'TEAM_NAME', 'DESK_CODE', 'DESK_NAME',
#        'RM_CODE', 'RM_NAME', 'Post TRAN_AMT_VAL', 'Post TRAN_AMT'],
#       dtype='object')

# %%
print(df['Post TRAN_AMT_VAL'].mean())
print(df['Post TRAN_AMT_VAL'].min())
print(df['Post TRAN_AMT_VAL'].max())
print(df['Post TRAN_AMT_VAL'].median())
print(df['Post TRAN_AMT_VAL'].mode())
print(df['Post TRAN_AMT_VAL'].std())
# Out:
# 7826612.679776077
# 5000000
# 250000000
# 6180227.5
# 0    5000000
# Name: Post TRAN_AMT_VAL, dtype: int64
# 5603334.005500579

# %%
#copy initial data set
df1= df.copy()
df1.head()
# Out:
#         CUST_ID  DTH_INIT_SOL_ID        TRAN_DATE  Post Customer  \
# 0     160450435              160  11/30/2022 0:00      160450435
# 1     160402430              160  11/15/2022 0:00      160402430
# 2     160417547              160  12/29/2022 0:00      160417547
# 3     160416279              160   1/19/2023 0:00      160416279
# 4     160416279              297   1/20/2023 0:00      160416279
# ...         ...              ...              ...            ...
# 4995  110082923              110   11/3/2022 0:00      110082923
# 4996  110082923              110  11/18/2022 0:00      110082923
# 4997  110082923              110  11/21/2022 0:00      110082923
# 4998  110082923              110  11/22/2022 0:00      110082923
# 4999  110082923              110  11/24/2022 0:00      110082923
#
#      PART_TRAN_TYPE TRAN_SUB_TYPE BU_CODE              BU_NAME GROUP_CODE  \
# 0            CREDIT            NR       6         NORTH REGION        605
# ...

# %%
#Group summaries: Single
df1.groupby("BU_NAME")["Post TRAN_AMT_VAL"].sum()
# Out:
# BU_NAME
# AGB FREECODE 6                         204009300
# COMMERCIAL BANKING                    4519177802
# CORPORATE BANKING                     1796527144
# CORPORATE OFFICE                        68275139
# CPC DEFAULT FREE CODE 6                585402675
# LAGOS & WEST REGION                  23049517223
# NORTH REGION                         54705773797
# PUBLIC SECTOR GROUP                    775501642
# RETAIL OTHERS                          334311000
# SOUTH REGION                         23237431045
# TREASURY & FINANCIAL INSTITUTIONS      169880500
# USSD FREECODE 6                        714530800
# Name: Post TRAN_AMT_VAL, dtype: int64

# %%
#Group summaries: Multiple
df1.groupby("BU_NAME")["Post TRAN_AMT_VAL"].agg([sum, min, max])
# Out:
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\2702068728.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df1.groupby("BU_NAME")["Post TRAN_AMT_VAL"].agg([sum, min, max])
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\2702068728.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df1.groupby("BU_NAME")["Post TRAN_AMT_VAL"].agg([sum, min, max])
# ...

# %%
#Group summaries: Multiple
df1.groupby(["BU_NAME", "GROUP_NAME"])["Post TRAN_AMT_VAL"].agg([sum, min, max])
# Out:
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\3868750415.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df1.groupby(["BU_NAME", "GROUP_NAME"])["Post TRAN_AMT_VAL"].agg([sum, min, max])
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\3868750415.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df1.groupby(["BU_NAME", "GROUP_NAME"])["Post TRAN_AMT_VAL"].agg([sum, min, max])
# ...

# %%
import numpy as np
df1.pivot_table(values="Post TRAN_AMT_VAL", index="BU_NAME", aggfunc= np.median)
# Out:
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\1452777707.py:2: FutureWarning: The provided callable <function median at 0x000001D17B3EC2C0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df1.pivot_table(values="Post TRAN_AMT_VAL", index="BU_NAME", aggfunc= np.median)
#                                    Post TRAN_AMT_VAL
# BU_NAME
# AGB FREECODE 6                             6900000.0
# COMMERCIAL BANKING                         7250000.0
# CORPORATE BANKING                          6400753.5
# CORPORATE OFFICE                           8000000.0
# CPC DEFAULT FREE CODE 6                    6000000.0
# LAGOS & WEST REGION                        6100000.0
# NORTH REGION                               6376000.0
# PUBLIC SECTOR GROUP                        8000000.0
# RETAIL OTHERS                              7000000.0
# ...

# %%
import numpy as np
df1.pivot_table(values="Post TRAN_AMT_VAL", index=["BU_NAME", "GROUP_NAME"], aggfunc= [np.mean, np.sum, np.median])
# Out:
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\2338842276.py:2: FutureWarning: The provided callable <function mean at 0x000001D17B250CC0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df1.pivot_table(values="Post TRAN_AMT_VAL", index=["BU_NAME", "GROUP_NAME"], aggfunc= [np.mean, np.sum, np.median])
# C:\Users\Hp 1030\AppData\Local\Temp\ipykernel_22060\2338842276.py:2: FutureWarning: The provided callable <function sum at 0x000001D17B227880> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df1.pivot_table(values="Post TRAN_AMT_VAL", index=["BU_NAME", "GROUP_NAME"], aggfunc= [np.mean, np.sum, np.median])
# ...

# %%
 #subsetting Pandas
df1[df1["BU_NAME"].isin(["COMMERCIAL BANKING","PUBLIC SECTOR GROUP"])]
# Out:
#         CUST_ID  DTH_INIT_SOL_ID        TRAN_DATE  Post Customer  \
# 2866  215027548              215   1/30/2023 0:00      215027548
# 2867  215027548              215   1/30/2023 0:00      215027548
# 2873  554002666              554   1/17/2023 0:00      554002666
# 2874  212020635              370  12/20/2022 0:00      212020635
# 2875  212020635              370    1/3/2023 0:00      212020635
# ...         ...              ...              ...            ...
# 3855  466407899              466  12/15/2022 0:00      466407899
# 3856  466407899              466  12/20/2022 0:00      466407899
# 3857  466407899              466   1/10/2023 0:00      466407899
# 3858  466407899              466   1/17/2023 0:00      466407899
# 3859  466407899              466   1/18/2023 0:00      466407899
#
#      PART_TRAN_TYPE TRAN_SUB_TYPE BU_CODE              BU_NAME GROUP_CODE  \
# 2866         CREDIT            NR       3  PUBLIC SECTOR GROUP        302
# ...

# %%
df1[df1["GROUP_NAME"].isin(["CMB - NORTH","CMB - SOUTH EAST"])].count()
# Out:
# CUST_ID              265
# DTH_INIT_SOL_ID      265
# TRAN_DATE            265
# Post Customer        265
# PART_TRAN_TYPE       265
# TRAN_SUB_TYPE        265
# BU_CODE              265
# BU_NAME              265
# GROUP_CODE           265
# GROUP_NAME           265
# TEAM_CODE            265
# TEAM_NAME            265
# DESK_CODE            265
# DESK_NAME            265
# RM_CODE              265
# RM_NAME              265
# Post TRAN_AMT_VAL    265
# Post TRAN_AMT        265
# dtype: int64

# %%
#loc and iloc filtering

df1.loc[["BU_NAME", "GROUP_NAME"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #loc and iloc filtering
# ----> 3 df1.loc[["BU_NAME", "GROUP_NAME"]]
#
# NameError: name 'df1' is not defined

# %%
df_dummy = pd.DataFrame( 
{ 
"city": ["London", "London", "Leeds", "Leeds", "Bristol"], 
"year": [2023, 2024, 2023, 2024, 2024], 
"sales": [120, 140, 90, 95, 110], 
"cost": [70, 80, 55, 60, 65], 
}, 
index=["a","b","c","d","e"]  # explicit row labels 
)

# %%
df_dummy.head()
# Out:
#       city  year  sales  cost
# a   London  2023    120    70
# b   London  2024    140    80
# c    Leeds  2023     90    55
# d    Leeds  2024     95    60
# e  Bristol  2024    110    65

# %%
#### loc: label based indexing

df_dummy.loc["b"]
# Out:
# city     London
# year       2024
# sales       140
# cost         80
# Name: b, dtype: object

# %%
df_dummy.loc[["b", "d", "e"]]
# Out:
#       city  year  sales  cost
# b   London  2024    140    80
# d    Leeds  2024     95    60
# e  Bristol  2024    110    65

# %%
# selecting rows and columns by label

df_dummy.loc["b", "sales"]
# Out:
# np.int64(140)

# %%
df_dummy.loc[["b", "d"], ["city", "sales"]]
# Out:
#      city  sales
# b  London    140
# d   Leeds     95

# %%
# slice by label

df_dummy.loc["b":"e", "city":"sales"]
# Out:
#       city  year  sales
# b   London  2024    140
# c    Leeds  2023     90
# d    Leeds  2024     95
# e  Bristol  2024    110

# %%
city_l= df_dummy["city"].str.startswith("L")

print(city_l)
# Out:
# a     True
# b     True
# c     True
# d     True
# e    False
# Name: city, dtype: bool

# %%
df_dummy[df_dummy["city"].str.startswith("L")]
# Out:
#      city  year  sales  cost
# a  London  2023    120    70
# b  London  2024    140    80
# c   Leeds  2023     90    55
# d   Leeds  2024     95    60

# %%
df_dummy.loc[lambda x: x["sales"]> x["cost"]*1.7, ["city", "sales", "cost"]]
# Out:
#      city  sales  cost
# a  London    120    70
# b  London    140    80

# %%
#creating new columns

df_dummy["profit"]= df_dummy["sales"]- df_dummy["cost"]
df_dummy
# Out:
#       city    year  sales  cost  profit
# a   London  2023.0  120.0  70.0    50.0
# b   London  2024.0  140.0  80.0    60.0
# c    Leeds  2023.0   90.0  55.0    35.0
# d    Leeds  2024.0   95.0  60.0    35.0
# e  Bristol  2024.0  110.0  65.0    45.0
# f  cardiff  2026.0  220.0  75.0   145.0

# %%
df_dummy.loc["f"]={
    "city":"cardiff",
    "year":2026,
    "sales":220,
    "cost":75
}

# %%
df_dummy
# Out:
#            city    year  sales  cost  profit
# a        London  2023.0  120.0  70.0    50.0
# b        London  2024.0  140.0  80.0    60.0
# c         Leeds  2023.0   90.0  55.0    35.0
# d         Leeds  2024.0   95.0  60.0    35.0
# e       Bristol  2024.0  110.0  65.0    45.0
# profit      NaN     NaN    NaN   NaN     NaN
# f       cardiff  2026.0  220.0  75.0     NaN

# %%
df_dummy= df_dummy.drop(index="profit")

# %%
df_dummy
# Out:
#       city    year  sales  cost  profit
# a   London  2023.0  120.0  70.0    50.0
# b   London  2024.0  140.0  80.0    60.0
# c    Leeds  2023.0   90.0  55.0    35.0
# d    Leeds  2024.0   95.0  60.0    35.0
# e  Bristol  2024.0  110.0  65.0    45.0
# f  cardiff  2026.0  220.0  75.0     NaN

# %%
df1.columns
# Out:
# Index(['CUST_ID', 'DTH_INIT_SOL_ID', 'TRAN_DATE', 'Post Customer',
#        'PART_TRAN_TYPE', 'TRAN_SUB_TYPE', 'BU_CODE', 'BU_NAME', 'GROUP_CODE',
#        'GROUP_NAME', 'TEAM_CODE', 'TEAM_NAME', 'DESK_CODE', 'DESK_NAME',
#        'RM_CODE', 'RM_NAME', 'Post TRAN_AMT_VAL', 'Post TRAN_AMT'],
#       dtype='object')

# %%
df1_BU_NAME= df1.set_index("BU_NAME")
print(df1_BU_NAME)
# Out:
#                 CUST_ID  DTH_INIT_SOL_ID        TRAN_DATE  Post Customer  \
# BU_NAME
# NORTH REGION  160450435              160  11/30/2022 0:00      160450435
# NORTH REGION  160402430              160  11/15/2022 0:00      160402430
# NORTH REGION  160417547              160  12/29/2022 0:00      160417547
# NORTH REGION  160416279              160   1/19/2023 0:00      160416279
# NORTH REGION  160416279              297   1/20/2023 0:00      160416279
# ...                 ...              ...              ...            ...
# NORTH REGION  160007006              160   1/19/2023 0:00      160007006
# NORTH REGION  160007700              160   1/24/2023 0:00      160007700
# NORTH REGION  161002647              160   1/20/2023 0:00      161002647
# NORTH REGION  160428214              160  11/10/2022 0:00      160428214
# NORTH REGION  160428214              160   1/19/2023 0:00      160428214
#
#              PART_TRAN_TYPE TRAN_SUB_TYPE BU_CODE GROUP_CODE      GROUP_NAME  \
# ...

# %%
df1["BU_NAME"].unique()
# Out:
# array(['NORTH REGION', 'SOUTH REGION', 'LAGOS & WEST REGION',
#        'USSD FREECODE 6', 'PUBLIC SECTOR GROUP', 'COMMERCIAL BANKING',
#        'RETAIL OTHERS', 'CORPORATE BANKING', nan,
#        'CPC DEFAULT FREE CODE 6', 'AGB FREECODE 6',
#        'TREASURY & FINANCIAL INSTITUTIONS', 'CORPORATE OFFICE'],
#       dtype=object)

# %%
df1_BU_NAME.loc[['NORTH REGION','CORPORATE BANKING'], ["TRAN_DATE", "GROUP_CODE"]]
# Out:
#                          TRAN_DATE GROUP_CODE
# BU_NAME
# NORTH REGION       11/30/2022 0:00        605
# NORTH REGION       11/15/2022 0:00        605
# NORTH REGION       12/29/2022 0:00        605
# NORTH REGION        1/19/2023 0:00        605
# NORTH REGION        1/20/2023 0:00        605
# ...                            ...        ...
# CORPORATE BANKING    1/5/2023 0:00        203
# CORPORATE BANKING    1/9/2023 0:00        203
# CORPORATE BANKING   1/11/2023 0:00        203
# CORPORATE BANKING   1/12/2023 0:00        203
# CORPORATE BANKING   1/24/2023 0:00        203
#
# [6984 rows x 2 columns]

# %%
df1_BU_NAME.loc[df1_BU_NAME["Post TRAN_AMT_VAL"]>5000000]
# Out:
#                            CUST_ID  DTH_INIT_SOL_ID        TRAN_DATE  \
# BU_NAME
# CPC DEFAULT FREE CODE 6  360421912              360   1/24/2023 0:00
# CPC DEFAULT FREE CODE 6  317001671              317   1/23/2023 0:00
# CPC DEFAULT FREE CODE 6  317001671              317   1/24/2023 0:00
# NaN                      663411385              663  12/12/2022 0:00
# NaN                      663411385              663  12/19/2022 0:00
# ...                            ...              ...              ...
# NORTH REGION             160007006              160   1/19/2023 0:00
# NORTH REGION             160007700              160   1/24/2023 0:00
# NORTH REGION             161002647              160   1/20/2023 0:00
# NORTH REGION             160428214              160  11/10/2022 0:00
# NORTH REGION             160428214              160   1/19/2023 0:00
#
#                          Post Customer PART_TRAN_TYPE TRAN_SUB_TYPE BU_CODE  \
# BU_NAME
# ...

# %%
df_dummy = pd.DataFrame( 
{ 
"city": ["London", "London", "Leeds", "Leeds", "Bristol"], 
"year": [2023, 2024, 2023, 2024, 2024], 
"sales": [120, 140, 90, 95, 110], 
"cost": [70, 80, 55, 60, 65], 
}, 
index=["a","b","c","d","e"]  # explicit row labels 
)

# %%
df_dummy.head()
# Out:
#       city  year  sales  cost
# a   London  2023    120    70
# b   London  2024    140    80
# c    Leeds  2023     90    55
# d    Leeds  2024     95    60
# e  Bristol  2024    110    65

# %%
df_dummy.iloc[[1,2],[1,2]] #selecting calls last value
# Out:
#    year  sales
# b  2024    140
# c  2023     90

# %%
df_dummy.iloc[0:3, 0:3] #intervals doesnt call the last value
# Out:
#      city  year  sales
# a  London  2023    120
# b  London  2024    140
# c   Leeds  2023     90

# %%
#matplotlib
#seaborn

import matplotlib.pyplot as plt

print (df_dummy.isna())
# Out:
#     city   year  sales   cost
# a  False  False  False  False
# b  False  False  False  False
# c  False  False  False  False
# d  False  False  False  False
# e  False  False  False  False

# %%
df_dummy.plot(kind="bar")

plt.show()
